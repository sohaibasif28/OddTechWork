# %%
import pandas as pd

# %%
data = pd.read_csv('Full_Finalized_numeric_data_for_training.csv')

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data_copy = data.copy()

# %%
train_data = data_copy.drop(["Duration","Label"],axis=1)

# %%
train_data
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 0          18      5768             0              87                    1
# 1          18      4600             1              83                    3
# 2          18      4373             0               2                    1
# 3          18      4373             1              62                    3
# 4          18      3375             0              50                    1
# ...       ...       ...           ...             ...                  ...
# 335869     16       651             1              69                    3
# 335870     16      1520             1              84                    1
# 335871     16      3163             0              88                    3
# 335872     16      9064             0              94                    3
# 335873     16      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# 0              0    86429           0                    6
# 1              1    85939           1                    3
# 2              0    85712           0                   13
# 3              1    85736           1                    3
# 4              0    85335           0                   12
# ...          ...      ...         ...                  ...
# 335869         1    19468           1                    3
# 335870         0    19468           0                    8
# 335871         1    19468           0                    8
# 335872         1    19468           0                    6
# 335873         0    19468           0                   16
#
#         PresenceOfCreditCard  CreditRating  hour
# 0                          0             1    12
# 1                          1             7     9
# 2                          0             4    15
# 3                          1             2     9
# 4                          0             4    13
# ...                      ...           ...   ...
# 335869                     1             8    12
# 335870                     0             1     9
# 335871                     1             1    14
# 335872                     1             8    12
# 335873                     1             1    12
#
# [335874 rows x 12 columns]

# %% [markdown]
# # SPLITING DATA

# %%
from sklearn.model_selection import train_test_split

# Seperating Data "sklearn" buildin Model
X = train_data
# Seperating Variables
y = data['Label']

# Spliting Data into two type(train, test)
train_X, test_X, train_y, test_y = train_test_split(X, y,test_size = 0.10, random_state = 0)
print('Train Data',train_X,'\n Lenght of train Data', len(train_X))
print('Test Data',test_X,'\n Lenght of Test Data', len(test_X))
# Out:
# Train Data         state  cityname  persongender  personexactage  personmaritalstatus  \
# 113854     27      1453             0              71                    2
# 18618       0      5899             0              50                    3
# 244037     26      4454             1              29                    2
# 254665      3      6146             1              77                    0
# 71726      19      4146             0              83                    3
# ...       ...       ...           ...             ...                  ...
# 122579     27      1739             1              79                    2
# 304137     14       179             1              72                    3
# 152315     24      9154             2              69                    3
# 117952     27      4704             0              79                    3
# 305711     14      6791             0               2                    2
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# 113854         0    20784           0                    8
# 18618          0    93257           0                   19
# 244037         1    68008           1                    9
# 254665         1    87401           1                   19
# 71726          1    50638           1                   17
# ...          ...      ...         ...                  ...
# 122579         1    21030           1                    6
# 304137         1    18704           0                    5
# 152315         1    20636           1                   15
# 117952         1    21014           0                    6
# 305711         0    19426           0                   15
#
#         PresenceOfCreditCard  CreditRating  Duration
# 113854                     1             4        17
# 18618                      1             1         0
# 244037                     1             8        18
# 254665                     1             6         0
# 71726                      1             1         0
# ...                      ...           ...       ...
# 122579                     1             1        34
# 304137                     0             6        21
# 152315                     1             1         0
# 117952                     1             7        48
# 305711                     0             1         0
#
# [302286 rows x 12 columns]
#  Lenght of train Data 302286
# Test Data         state  cityname  persongender  personexactage  personmaritalstatus  \
# 282850      5      1550             1              40                    3
# 15155       0      2036             0               2                    2
# 171399     10      1159             2               2                    1
# 131100     22      3805             1              81                    3
# 48759      21      1015             1              27                    2
# ...       ...       ...           ...             ...                  ...
# 72630      19       999             2               2                    3
# 324797     29       441             0              40                    3
# 327881     29      4058             0              64                    3
# 196747      7      5134             1              37                    3
# 165555      1      7679             0              81                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# 282850         0    11801           1                   16
# 15155          1    92108           1                   15
# 171399         0    48134           1                    2
# 131100         1    20852           1                   14
# 48759          0    95821           0                    0
# ...          ...      ...         ...                  ...
# 72630          1    52601           1                   18
# 324797         1    16426           1                    6
# 327881         0    19567           1                    9
# 196747         1    63090           1                   16
# 165555         1    49444           1                   19
#
#         PresenceOfCreditCard  CreditRating  Duration
# 282850                     1             7         3
# 15155                      1             1         0
# 171399                     1             7         0
# 131100                     1             1        12
# 48759                      1             1         0
# ...                      ...           ...       ...
# 72630                      1             6        21
# 324797                     1             1        21
# 327881                     1             1         0
# 196747                     1             8        21
# 165555                     1             4        26
#
# [33588 rows x 12 columns]
#  Lenght of Test Data 33588

# %%
#showing shape of splited data
print(train_X.shape, test_X.shape, train_y.shape, test_y.shape)
# Out:
# (302286, 12) (33588, 12) (302286,) (33588,)

# %% [markdown]
# # Training

# %%
from sklearn.linear_model import LinearRegression

# Using Regression Model
regression = LinearRegression()
regression.fit(train_X, train_y)
print('Model Trained')
# Out:
# Model Trained

# %% [markdown]
# # Predicting Data

# %%
pred_test_data = regression.predict(test_X)

# %%
pred_test_data
# Out:
# array([0.44474956, 0.46883896, 0.45471467, ..., 0.44558032, 0.51440413,
#        0.52228904])

# %%
regression.score(test_X,test_y)
# Out:
# 0.11541944310239316

# %%
pred_test_dataframe =pd.DataFrame(test_X)

# %%
pred_test_dataframe
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 282850      5      1550             1              40                    3
# 15155       0      2036             0               2                    2
# 171399     10      1159             2               2                    1
# 131100     22      3805             1              81                    3
# 48759      21      1015             1              27                    2
# ...       ...       ...           ...             ...                  ...
# 72630      19       999             2               2                    3
# 324797     29       441             0              40                    3
# 327881     29      4058             0              64                    3
# 196747      7      5134             1              37                    3
# 165555      1      7679             0              81                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# 282850         0    11801           1                   16
# 15155          1    92108           1                   15
# 171399         0    48134           1                    2
# 131100         1    20852           1                   14
# 48759          0    95821           0                    0
# ...          ...      ...         ...                  ...
# 72630          1    52601           1                   18
# 324797         1    16426           1                    6
# 327881         0    19567           1                    9
# 196747         1    63090           1                   16
# 165555         1    49444           1                   19
#
#         PresenceOfCreditCard  CreditRating  Duration
# 282850                     1             7         3
# 15155                      1             1         0
# 171399                     1             7         0
# 131100                     1             1        12
# 48759                      1             1         0
# ...                      ...           ...       ...
# 72630                      1             6        21
# 324797                     1             1        21
# 327881                     1             1         0
# 196747                     1             8        21
# 165555                     1             4        26
#
# [33588 rows x 12 columns]

# %%
pred_test_dataframe['Actural Duration'] = test_y

# %%
pred_test_dataframe['Predict Duration'] = pred_test_data

# %%
train_data
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 0          18      5768             0              87                    1
# 1          18      4600             1              83                    3
# 2          18      4373             0               2                    1
# 3          18      4373             1              62                    3
# 4          18      3375             0              50                    1
# ...       ...       ...           ...             ...                  ...
# 335869     16       651             1              69                    3
# 335870     16      1520             1              84                    1
# 335871     16      3163             0              88                    3
# 335872     16      9064             0              94                    3
# 335873     16      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# 0              0    86429           0                    6
# 1              1    85939           1                    3
# 2              0    85712           0                   13
# 3              1    85736           1                    3
# 4              0    85335           0                   12
# ...          ...      ...         ...                  ...
# 335869         1    19468           1                    3
# 335870         0    19468           0                    8
# 335871         1    19468           0                    8
# 335872         1    19468           0                    6
# 335873         0    19468           0                   16
#
#         PresenceOfCreditCard  CreditRating  Duration
# 0                          0             1         0
# 1                          1             7        14
# 2                          0             4        24
# 3                          1             2         0
# 4                          0             4         0
# ...                      ...           ...       ...
# 335869                     1             8         0
# 335870                     0             1         0
# 335871                     1             1         0
# 335872                     1             8         0
# 335873                     1             1         0
#
# [335874 rows x 12 columns]

# %%
train_data = data.iloc[:,:-2]

# %%
train_data
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 0          18      5768             0              87                    1
# 1          18      4600             1              83                    3
# 2          18      4373             0               2                    1
# 3          18      4373             1              62                    3
# 4          18      3375             0              50                    1
# ...       ...       ...           ...             ...                  ...
# 335869     16       651             1              69                    3
# 335870     16      1520             1              84                    1
# 335871     16      3163             0              88                    3
# 335872     16      9064             0              94                    3
# 335873     16      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# 0              0    86429           0                    6
# 1              1    85939           1                    3
# 2              0    85712           0                   13
# 3              1    85736           1                    3
# 4              0    85335           0                   12
# ...          ...      ...         ...                  ...
# 335869         1    19468           1                    3
# 335870         0    19468           0                    8
# 335871         1    19468           0                    8
# 335872         1    19468           0                    6
# 335873         0    19468           0                   16
#
#         PresenceOfCreditCard  CreditRating  Duration
# 0                          0             1         0
# 1                          1             7        14
# 2                          0             4        24
# 3                          1             2         0
# 4                          0             4         0
# ...                      ...           ...       ...
# 335869                     1             8         0
# 335870                     0             1         0
# 335871                     1             1         0
# 335872                     1             8         0
# 335873                     1             1         0
#
# [335874 rows x 12 columns]

# %%
# data

# %%
# Import necessary modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
# from sklearn.datasets import load_iris

# Loading data
Data = data

# Create feature and target arrays
X = train_data
y =  Data['Label']

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0)

knn = KNeighborsClassifier(n_neighbors=8)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
prediction = knn.predict(X_test)
prediction
# Out:
# array([0, 0, 1, ..., 1, 0, 1], dtype=int64)

# %%
print(knn.score(X_test, y_test))
# Out:
# 0.742478600669892

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
neighbors = np.arange(1, 9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))
 
# Loop over K values
for i, k in enumerate(neighbors):
    
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
     
    # Compute training and test data accuracy
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)
plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')
 
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
acc=knn.score(X_test, y_test)

# %%
print(str(round(acc*100,2))+'%')
# Out:
# 71.45%

# %%
# train_data.corr()

# %%
knn.predict([[18,4600,1,83,3,1,85939,1,3,1,7,9]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(train_data,data['Label'],test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\TRAINE~1\AppData\Local\Temp/ipykernel_7376/1274452856.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test = train_test_split(train_data,data['Label'],test_size=0.2)
#
# NameError: name 'train_data' is not defined

# %%
# KNN Algo(test size 40 % accuracy 71%)
# KNN Algo(test size 30 % accuracy 73%)
# KNN Algo(test size 20 % accuracy 74.2%)

# %%
# f
# fg
# fg
# fg
# fh
# f
# h
# h
# fh
# f
# hf
# h
# f
# h
d #ghgh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-852a41def181> in <module>
#      13 # f
#      14 # h
# ---> 15 d #ghgh
#
# NameError: name 'd' is not defined
