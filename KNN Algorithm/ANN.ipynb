# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
pip install tensorflow
# Out:
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=2fdc54b1cb58de36064524a67caf7f7655c92b48d2b010a54f34e24d824476d4
#   Stored in directory: c:\users\trainee9\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv('Full_Finalized_numeric_data_for_training.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  state  cityname  persongender  personexactage  \
# 0           0     18      5768             0              87
# 1           1     18      4600             1              83
# 2           2     18      4373             0               2
# 3           3     18      4373             1              62
# 4           4     18      3375             0              50
#
#    personmaritalstatus  traveler  ZipCode  investment  estimatedincomecode  \
# 0                    1         0    86429           0                    6
# 1                    3         1    85939           1                    3
# 2                    1         0    85712           0                   13
# 3                    3         1    85736           1                    3
# 4                    1         0    85335           0                   12
#
#    PresenceOfCreditCard  CreditRating  Duration  hour  Label
# 0                     0             1         0    12      0
# ...

# %%
data.shape
# Out:
# (335874, 15)

# %%
labels = data['Label']

# %%
labels
# Out:
# 0         0
# 1         1
# 2         1
# 3         0
# 4         0
#          ..
# 335869    0
# 335870    0
# 335871    0
# 335872    0
# 335873    0
# Name: Label, Length: 335874, dtype: int64

# %%
shuffledData = data.sample(frac = 1, replace = True).reset_index(drop=True)
shuffledData
# Out:
#         Unnamed: 0  state  cityname  persongender  personexactage  \
# 0            48730     21      5994             1               2
# 1           306779     14      2470             1              61
# 2           320905     31      5670             1              63
# 3             3651      0      9202             1              75
# 4           178732      8      9809             2              77
# ...            ...    ...       ...           ...             ...
# 335869      328393     29      2130             0              22
# 335870       20933      0      5345             1              69
# 335871       83215     20      5716             1              55
# 335872       64113     25      1332             0              65
# 335873      227648     26      5626             0              66
#
#         personmaritalstatus  traveler  ZipCode  investment  \
# 0                         1         0    90011           0
# ...

# %%
data['Label'].value_counts()
# Out:
# 0    173632
# 1    162242
# Name: Label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# Let's say we want to split the data in 80:10:10 for train:valid:test dataset
train_size=0.8

X = shuffledData.drop(columns = ['Label', 'Duration', 'Unnamed: 0', 'state','personmaritalstatus', 'ZipCode']).copy()
# Encoding Labels(one-hot-endcoding)
y = to_categorical(shuffledData['Label'])

# In the first step we will split the data in training and remaining dataset
train_data, X_rem, train_labels, y_rem = train_test_split(X,y, train_size=0.8)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# we have to define valid_size=0.5 (that is 50% of remaining data)
#test_size = 0.2
valid_data, test_data, valid_labels, test_labels = train_test_split(X_rem,y_rem, test_size=0.2)

print(train_data.shape), print(train_labels.shape)
print(valid_data.shape), print(valid_labels.shape)
print(test_data.shape), print(test_labels.shape)
# Out:
# (268699, 9)
# (268699, 2)
# (53740, 9)
# (53740, 2)
# (13435, 9)
# (13435, 2)
# (None, None)

# %%
X
# Out:
#         cityname  persongender  personexactage  traveler  investment  \
# 0           5994             1               2         0           0
# 1           2470             1              61         1           1
# 2           5670             1              63         1           0
# 3           9202             1              75         1           0
# 4           9809             2              77         0           1
# ...          ...           ...             ...       ...         ...
# 335869      2130             0              22         1           1
# 335870      5345             1              69         1           0
# 335871      5716             1              55         1           1
# 335872      1332             0              65         1           1
# 335873      5626             0              66         1           0
#
#         estimatedincomecode  PresenceOfCreditCard  CreditRating  hour
# ...

# %%
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(60, activation='relu', input_shape=(train_data.shape[1],)))
    model.add(layers.Dense(30, activation='relu'))
    model.add(layers.Dense(20, activation='sigmoid'))
    model.add(layers.Dense(2, activation='sigmoid'))
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
num_epochs = 5
model = build_model()
# Train the model (in silent mode, verbose=0)
model.fit(train_data, train_labels, epochs=num_epochs, batch_size=1)
# Evaluate the model on the validation data
#val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
# Out:
# Epoch 1/5
# 268699/268699 [==============================] - 453s 2ms/step - loss: 0.6966 - accuracy: 0.5042
# Epoch 2/5
# 268699/268699 [==============================] - 434s 2ms/step - loss: 0.6962 - accuracy: 0.5068
# Epoch 3/5
# 268699/268699 [==============================] - 432s 2ms/step - loss: 0.6962 - accuracy: 0.5045
# Epoch 4/5
# 268699/268699 [==============================] - 427s 2ms/step - loss: 0.6953 - accuracy: 0.5078
# Epoch 5/5
# 268699/268699 [==============================] - 451s 2ms/step - loss: 0.6953 - accuracy: 0.5078

# %%
# Out:
#         cityname  persongender  personexactage  traveler  investment  \
# 0           4980             1              97         0           0
# 1           1579             1              56         0           1
# 2           9599             1              38         1           1
# 3           5670             0              78         1           0
# 4           5208             2               2         0           1
# ...          ...           ...             ...       ...         ...
# 335869      2734             1              73         1           0
# 335870      1242             2              79         0           1
# 335871      7505             1              89         1           0
# 335872      8734             0              47         1           0
# 335873     10224             1              48         1           1
#
#         estimatedincomecode  PresenceOfCreditCard  CreditRating  Duration  \
# ...
