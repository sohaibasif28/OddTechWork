# %%
import pandas as pd

# %%
df = pd.read_csv('Full_Finalized_numeric_data_for_training.csv')

# %%
df
# Out:
#         Unnamed: 0  state  cityname  persongender  personexactage  \
# 0                0     18      5768             0              87
# 1                1     18      4600             1              83
# 2                2     18      4373             0               2
# 3                3     18      4373             1              62
# 4                4     18      3375             0              50
# ...            ...    ...       ...           ...             ...
# 335869      335869     16       651             1              69
# 335870      335870     16      1520             1              84
# 335871      335871     16      3163             0              88
# 335872      335872     16      9064             0              94
# 335873      335873     16      5988             0              75
#
#         personmaritalstatus  traveler  ZipCode  investment  \
# 0                         1         0    86429           0
# 1                         3         1    85939           1
# 2                         1         0    85712           0
# 3                         3         1    85736           1
# 4                         1         0    85335           0
# ...                     ...       ...      ...         ...
# 335869                    3         1    19468           1
# 335870                    1         0    19468           0
# 335871                    3         1    19468           0
# 335872                    3         1    19468           0
# 335873                    3         0    19468           0
#
#         estimatedincomecode  PresenceOfCreditCard  CreditRating  Duration  \
# 0                         6                     0             1         0
# 1                         3                     1             7        14
# 2                        13                     0             4        24
# 3                         3                     1             2         0
# 4                        12                     0             4         0
# ...                     ...                   ...           ...       ...
# 335869                    3                     1             8         0
# 335870                    8                     0             1         0
# 335871                    8                     1             1         0
# 335872                    6                     1             8         0
# 335873                   16                     1             1         0
#
#         hour  Label
# 0         12      0
# 1          9      1
# 2         15      1
# 3          9      0
# 4         13      0
# ...      ...    ...
# 335869    12      0
# 335870     9      0
# 335871    14      0
# 335872    12      0
# 335873    12      0
#
# [335874 rows x 15 columns]

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
target = df['Label']

# %%
features = df[['state', 'persongender', 'investment','PresenceOfCreditCard', 'CreditRating']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
from sklearn import metrics

# %%
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 51.41121829224723
